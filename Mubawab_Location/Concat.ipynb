# %%
import os
import pandas as pd #pip install pandas

# %%
df = pd.read_csv('/Users/Pro/Desktop/EtlProject_Web-Scraping/Mubawab_Location/4.csv',encoding='utf-8')
# df = pd.read_csv('data.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 df = pd.read_csv('/Users/Pro/Desktop/EtlProject_Web-Scraping/Mubawab_Location/4.csv',encoding='utf-8')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
# df1 = pd.read_excel(r'/Users/Pro/Desktop/EtlProject_Web-Scraping/Mubawab_Location/mubawabLocation1-20_clean.xlsx')
# df2 = pd.read_excel(r'/Users/Pro/Desktop/EtlProject_Web-Scraping/Mubawab_Location/mubawabLocation21-40_clean.xlsx')
# df3 = pd.read_excel(r'/Users/Pro/Desktop/EtlProject_Web-Scraping/Mubawab_Location/mubawabLocation41-60_clean.xlsx')
# # df1.drop(columns=['Unnamed: 0', 'Unnamed: 1'])
# df1
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 622           622         622
# 623           623         623
# 624           624         624
# 625           625         625
# 626           626         626
#
#                                                  Title  \
# 0                        Bel studio Haut standing neuf
# 1                 Très joli appartement sans vis à vis
# 2    Très joli studio HS plien gauthier avec belle ...
# 3    Location d’appartements du 3ème au 11 ème étag...
# 4    Studio meublé avec terasse et sans vis a vis b...
# ..                                                 ...
# 622                           Appartement vide à louer
# 623           Appartement chic bien entretenu a iberia
# 624                            Appartement 13ème Etage
# ...

# %%
values1 = df1[['Title','Location','Price','Caractéristiques','Pieces','Description','Pictures','Telephone','Durée','Surface']]
values2 = df2[['Title','Location','Price','Caractéristiques','Pieces','Description','Pictures','Telephone','Durée','Surface']]
values3 = df3[['Title','Location','Price','Caractéristiques','Pieces','Description','Pictures','Telephone','Durée','Surface']]

dataframes = [values1,values2,values3]
join = pd.concat(dataframes)
join.to_excel("mubawabLocation_all-data_clean.xlsx")
