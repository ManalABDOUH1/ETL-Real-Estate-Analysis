# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
#from gazpacho import Soup

URL = "https://www.avito.ma/fr/maroc/appartements-%C3%A0_vendre?o="
l = list()
for page in  range(1,4) :
    html_text = requests.get(URL+str(page)).content
    soup = bs(html_text,'html.parser') 
    
    ###            Partie Links             ###
    links =soup.find('div', class_='sc-116g21e-0 dOAHev').find('div',class_='sc-1nre5ec-0 dBrweF listing')
    #print(links)

# %%
for cont in links :
        #Lien du detail page
        try :
            Link = cont.find('a', class_='oan6tk-1 fFOxTQ').attrs['href']
        except :
            Link = 'Invalid'
        #print(Link)
        
        try :
            title = cont.find('span',class_='oan6tk-17 ewuNqy').text
        except :
            title = 'Invalid'
        #print(title)
        
        try:
            Price= cont.find('span',class_='sc-1x0vz2r-0 izsKzL oan6tk-15 cdJtEx').find('span').text
        except:
            Price ='Invalid'
        #print(Price)
        
        
        ###      Partie Liaison                  ###
        html_text2 = requests.get(Link).content
        soup2 = bs(html_text2,'html.parser')
        
        
        
        ###       Partie Content                 ###
        try:
            Ville = soup2.find('span',class_='sc-1x0vz2r-0 gCIGeB').text
        except:
            Ville = 'Invalid'
        #print(Ville)
        
        #Description
        try:
            description =soup2.find('p',class_='sc-ij98yj-0 iMUDvH').text
        except:
            description ='Invalid'
        #print(description)
        
        
        #surfaces
        try:
            surface = soup2.find('span',class_='sc-1x0vz2r-0 kUjmne').text
        except:
            surface ='Invalid'
        #print(surface)
        
        
        #nbr Chanmbres
        chambres= soup2.find('div', class_ = "sc-6p5md9-0 kqSvFR").find_all('div')[3].find('span',class_ = "sc-1x0vz2r-0 kUjmne").text.strip()
        #print(chambres)
            
        
        #Caractéristiques              
        features = soup2.find_all('li', class_='sc-qmn92k-0 bdihtW')
        caracList = list()
        for carac in features:
            try:
                feature = carac.find('span',class_='sc-1x0vz2r-0 iVDpDk').text
                caracList.append(feature)
            except :
                feature = 'Invalid'
        #print(caracList)
        
        
        #Pictures
        content = soup2.find('div', class_='slick-list')
        photos = content.find_all('div', class_='slick-slide')
        if photos is not None:
            photoList = list()
            for photo in photos:
                if photo is not None:
                    try:
                        picture = photo.find('picture').find('img').attrs['src']
                        photoList.append(picture)
                    except :
                        photoList = 'not defined'
                    #print(photoList)
            
            
        data = {"Title":title, "Ville":Ville, "Chambres":chambres, "Surfaces":surface, "Price":Price, "Caractéristiques":converted_list,"Pictures":photoList, "Description":description}
        l.append(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [275], in <cell line: 1>()
#      65 #print(caracList)
#      66
#      67
#      68 #Pictures
#      69 content = soup2.find('div', class_='slick-list')
# ---> 70 photos = content.find_all('div', class_='slick-slide')
#      71 if photos is not None:
#      72     photoList = list()
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
df = pd.DataFrame(l)

# %%
df
# Out:
#                                                Title       Ville Chambres  \
# 0            MEILLEURS APPARTEMENTS ECO A CHRIFIA R2   Marrakech        2
# 1                 DERNIERS APPARTEMENTS A LA GIRONDE  Casablanca        2
# 2             APPARTEMENTS NEUFS AU CENTRE DE TEMARA       Rabat        3
# 3         APPARTEMENTS TOP A MOHAMMEDIA PRES DU PARC  Casablanca        3
# 4            duplex 4 chambres 220m à rte ain chkef          Fès      10+
# 5  شقة للبيع بالطابق الأول بالهناء2 مساحتها 140 م...   Khouribga        3
# 6                 A 2 minutes de l'hôpital militaire       Rabat        2
# 7                            شقة محفظة 120m و garage   El Jadida        3
# 8                    Appartement rez-de-chaussée 87m   El Jadida        2
#
#   Surfaces      Price                                   Caractéristiques  \
# 0    57 m²    230 000  [Appartements, Vente, Aïn Sebaâ, 1, 200 DH, 1,...
# 1    74 m²    724 000  [Appartements, Vente, Aïn Sebaâ, 1, 200 DH, 1,...
# 2    80 m²    392 000  [Appartements, Vente, Aïn Sebaâ, 1, 200 DH, 1,...
# 3       --    480 000  [Appartements, Vente, Aïn Sebaâ, 1, 200 DH, 1,...
# 4   220 m²    780 000  [Appartements, Vente, Aïn Sebaâ, 1, 200 DH, 1,...
# 5   140 m²    900 000  [Appartements, Vente, Aïn Sebaâ, 1, 200 DH, 1,...
# 6   104 m²  1 350 000  [Appartements, Vente, Aïn Sebaâ, 1, 200 DH, 1,...
# 7   120 m²    580 000  [Appartements, Vente, Aïn Sebaâ, 1, 200 DH, 1,...
# 8    87 m²    530 000  [Appartements, Vente, Aïn Sebaâ, 1, 200 DH, 1,...
#
#                                             Pictures  \
# 0  [https://content.avito.ma/classifieds/images/1...
# 1  [https://content.avito.ma/classifieds/images/1...
# 2  [https://content.avito.ma/classifieds/images/1...
# 3  [https://content.avito.ma/classifieds/images/1...
# 4  [https://content.avito.ma/classifieds/images/1...
# 5  [https://content.avito.ma/classifieds/images/1...
# 6  [https://content.avito.ma/classifieds/images/1...
# 7  [https://content.avito.ma/classifieds/images/1...
# 8  [https://content.avito.ma/classifieds/images/1...
#
#                                          Description
# 0  Sur la route d’Amezmiz (vers Oasiria Beach), à...
# 1  La Résidence Assalam Ouled Ziane est située su...
# 2  A 5min de Rabat, au cœur de la ville de Temara...
# 3  Résidence Bougainvillier se situe à l’entrée S...
# 4  A un prix très raisonnable. Duplex 4 chambres ...
# 5  شقة للبيع بالطابق الأول بالهناء 2، مع إطلالة ع...
# 6  A 2 minutes du quartier de Hay Riad et de l'hô...
# 7                             شقة محفظة مساحتها 120m
# 8  Magnifique appartement a vendre a eljadida a H...

# %%
#  # Storing in Excel File   
df.to_excel("Avito7.xlsx")
