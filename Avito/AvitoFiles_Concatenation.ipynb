# %%
import os
import pandas as pd #pip install pandas

# %%
df1 = pd.read_excel(r'/Users/Dell/Avito/Avito1_10.xlsx')
df2 = pd.read_excel(r'/Users/Dell/Avito/Avito400_405.xlsx')
df3 = pd.read_excel(r'/Users/Dell/Avito/Avito390_397.xlsx')
df4 = pd.read_excel(r'/Users/Dell/Avito/Avito220_230.xlsx')
df5 = pd.read_excel(r'/Users/Dell/Avito/Avito87_95.xlsx')
df6 = pd.read_excel(r'/Users/Dell/Avito/Avito70_80.xlsx')
df7 = pd.read_excel(r'/Users/Dell/Avito/Avito56_66.xlsx')
df8 = pd.read_excel(r'/Users/Dell/Avito/Avito51_55.xlsx')
df9 = pd.read_excel(r'/Users/Dell/Avito/Avito21_30.xlsx')
df10 = pd.read_excel(r'/Users/Dell/Avito/Avito11_20.xlsx')
df11 = pd.read_excel(r'/Users/Dell/Avito/Avito6.xlsx')
df12 = pd.read_excel(r'/Users/Dell/Avito/Avito7.xlsx')

df1
# Out:
#      Unnamed: 0                                              Title  \
# 0             0                 شقق في وسط المدينة ذات جودة عالية
# 1             1  tres belle appartement a 3 chambres prix choquant
# 2             2                 Bel Appartement à Mhamid Marrakech
# 3             3    appartement haut standing 110m à rte ain chkef
# 4             4                     Appartement à Casablanca Oulfa
# ..          ...                                                ...
# 107         107                  Appartement en Vente à Casablanca
# 108         108  Appartement Neuf de 78m2 & Parking à Sidi Maarouf
# 109         109           شقق ممتازة بانسب الاثمان في وسط المدينة
# 110         110         Appartement a Bouznika avec un bon prix a
# 111         111                    maghnifique Appart hay mohmmadi
#
#           Ville  Chambres Surfaces    Price  \
# 0      Bouznika         6    75 m²  500 000
# 1    Casablanca         3    72 m²  250 000
# ...

# %%
values1 = df1[['Title','Ville','Chambres','Surfaces','Price','Caractéristiques','Pictures','Description']]
values2 = df2[['Title','Ville','Chambres','Surfaces','Price','Caractéristiques','Pictures','Description']]
values3 = df3[['Title','Ville','Chambres','Surfaces','Price','Caractéristiques','Pictures','Description']]
values4 = df4[['Title','Ville','Chambres','Surfaces','Price','Caractéristiques','Pictures','Description']]
values5 = df5[['Title','Ville','Chambres','Surfaces','Price','Caractéristiques','Pictures','Description']]
values6 = df6[['Title','Ville','Chambres','Surfaces','Price','Caractéristiques','Pictures','Description']]
values7 = df7[['Title','Ville','Chambres','Surfaces','Price','Caractéristiques','Pictures','Description']]
values8 = df8[['Title','Ville','Chambres','Surfaces','Price','Caractéristiques','Pictures','Description']]
values9 = df9[['Title','Ville','Chambres','Surfaces','Price','Caractéristiques','Pictures','Description']]
values10 = df10[['Title','Ville','Chambres','Surfaces','Price','Caractéristiques','Pictures','Description']]
values11 = df11[['Title','Ville','Chambres','Surfaces','Price','Caractéristiques','Pictures','Description']]
values12 = df12[['Title','Ville','Chambres','Surfaces','Price','Caractéristiques','Pictures','Description']]

dataframes = [values1,values2,values3,values4,values5,values6,values7,values8,values9,values10,values11,values12]
join = pd.concat(dataframes)
join.to_excel("Avito_all-data.xlsx")
